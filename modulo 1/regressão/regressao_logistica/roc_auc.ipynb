# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

pd.set_option('display.max_columns', 30)
dataset = load_breast_cancer()
X = pd.DataFrame(dataset.data, columns=[dataset.feature_names])
y = pd.Series(dataset.target)

# %%
X.head()
# Out:
#   mean radius mean texture mean perimeter mean area mean smoothness  \
# 0       17.99        10.38         122.80    1001.0         0.11840
# 1       20.57        17.77         132.90    1326.0         0.08474
# 2       19.69        21.25         130.00    1203.0         0.10960
# 3       11.42        20.38          77.58     386.1         0.14250
# 4       20.29        14.34         135.10    1297.0         0.10030
#
#   mean compactness mean concavity mean concave points mean symmetry  \
# 0          0.27760         0.3001             0.14710        0.2419
# 1          0.07864         0.0869             0.07017        0.1812
# 2          0.15990         0.1974             0.12790        0.2069
# 3          0.28390         0.2414             0.10520        0.2597
# 4          0.13280         0.1980             0.10430        0.1809
#
#   mean fractal dimension radius error texture error perimeter error  \
# 0                0.07871       1.0950        0.9053           8.589
# 1                0.05667       0.5435        0.7339           3.398
# 2                0.05999       0.7456        0.7869           4.585
# 3                0.09744       0.4956        1.1560           3.445
# 4                0.05883       0.7572        0.7813           5.438
#
#   area error smoothness error compactness error concavity error  \
# 0     153.40         0.006399           0.04904         0.05373
# 1      74.08         0.005225           0.01308         0.01860
# 2      94.03         0.006150           0.04006         0.03832
# 3      27.23         0.009110           0.07458         0.05661
# 4      94.44         0.011490           0.02461         0.05688
#
#   concave points error symmetry error fractal dimension error worst radius  \
# 0              0.01587        0.03003                0.006193        25.38
# 1              0.01340        0.01389                0.003532        24.99
# 2              0.02058        0.02250                0.004571        23.57
# 3              0.01867        0.05963                0.009208        14.91
# 4              0.01885        0.01756                0.005115        22.54
#
#   worst texture worst perimeter worst area worst smoothness worst compactness  \
# 0         17.33          184.60     2019.0           0.1622            0.6656
# 1         23.41          158.80     1956.0           0.1238            0.1866
# 2         25.53          152.50     1709.0           0.1444            0.4245
# 3         26.50           98.87      567.7           0.2098            0.8663
# 4         16.67          152.20     1575.0           0.1374            0.2050
#
#   worst concavity worst concave points worst symmetry worst fractal dimension
# 0          0.7119               0.2654         0.4601                 0.11890
# 1          0.2416               0.1860         0.2750                 0.08902
# 2          0.4504               0.2430         0.3613                 0.08758
# 3          0.6869               0.2575         0.6638                 0.17300
# 4          0.4000               0.1625         0.2364                 0.07678

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3, random_state=9)

modelo = LogisticRegression(C=80, penalty='l1', solver='liblinear', random_state=9, max_iter=10000)
modelo.fit(X_treino, y_treino)

resultado = modelo.score(X_teste, y_teste)
print("Acurácia: ", resultado)
# Out:
# Acurácia:  0.9707602339181286

# %%
predicoes = modelo.predict_proba(X_teste)

# %%
predicoes
# Out:
# array([[8.13377323e-01, 1.86622677e-01],
#        [1.51558031e-01, 8.48441969e-01],
#        [1.00000000e+00, 9.45436563e-15],
#        [1.01960816e-01, 8.98039184e-01],
#        [2.86003510e-05, 9.99971400e-01],
#        [1.00000000e+00, 7.70558441e-21],
#        [1.00000000e+00, 3.65013652e-15],
#        [1.00000000e+00, 6.01352671e-12],
#        [5.93065005e-06, 9.99994069e-01],
#        [9.99999992e-01, 8.34520533e-09],
#        [1.00000000e+00, 4.98556152e-14],
#        [6.59271065e-05, 9.99934073e-01],
#        [3.67298548e-06, 9.99996327e-01],
#        [4.82371178e-05, 9.99951763e-01],
#        [9.99999813e-01, 1.86523154e-07],
#        [2.17503688e-02, 9.78249631e-01],
#        [4.04799661e-06, 9.99995952e-01],
#        [3.74902096e-02, 9.62509790e-01],
#        [1.45560082e-06, 9.99998544e-01],
#        [4.38752179e-07, 9.99999561e-01],
#        [1.00000000e+00, 1.51803212e-35],
#        [4.74828421e-07, 9.99999525e-01],
#        [1.13716165e-03, 9.98862838e-01],
#        [1.00000000e+00, 1.51886469e-10],
#        [1.91834419e-03, 9.98081656e-01],
#        [3.60166886e-03, 9.96398331e-01],
#        [1.64754318e-03, 9.98352457e-01],
#        [3.71060589e-08, 9.99999963e-01],
#        [3.75933638e-06, 9.99996241e-01],
#        [1.00000000e+00, 5.68839050e-15],
#        [1.00000000e+00, 1.84833982e-14],
#        [8.27264848e-03, 9.91727352e-01],
#        [9.99129127e-01, 8.70873324e-04],
#        [9.92137543e-01, 7.86245708e-03],
#        [9.99999886e-01, 1.14205808e-07],
#        [1.00000000e+00, 9.75715527e-14],
#        [1.00000000e+00, 1.00587919e-15],
#        [1.24146673e-02, 9.87585333e-01],
#        [9.99999907e-01, 9.30756839e-08],
#        [4.41184868e-06, 9.99995588e-01],
#        [3.94607784e-01, 6.05392216e-01],
#        [2.36112466e-01, 7.63887534e-01],
#        [1.56552563e-04, 9.99843447e-01],
#        [1.80682600e-05, 9.99981932e-01],
#        [6.06853587e-05, 9.99939315e-01],
#        [3.04363359e-07, 9.99999696e-01],
#        [8.43139734e-01, 1.56860266e-01],
#        [1.00000000e+00, 4.18107439e-22],
#        [1.60806293e-01, 8.39193707e-01],
#        [9.99944514e-01, 5.54860633e-05],
#        [7.87576908e-01, 2.12423092e-01],
#        [5.94263538e-04, 9.99405736e-01],
#        [3.22866135e-06, 9.99996771e-01],
#        [8.78157110e-06, 9.99991218e-01],
#        [1.00000000e+00, 3.44413305e-18],
#        [2.70817853e-04, 9.99729182e-01],
#        [7.15236330e-05, 9.99928476e-01],
#        [1.00000000e+00, 3.65720693e-19],
#        [5.11628173e-04, 9.99488372e-01],
#        [8.29000695e-05, 9.99917100e-01],
#        [9.99936762e-01, 6.32383797e-05],
#        [9.99959107e-01, 4.08934231e-05],
#        [1.00000000e+00, 3.10393067e-18],
#        [2.94324704e-04, 9.99705675e-01],
#        [6.35362171e-05, 9.99936464e-01],
#        [8.03373001e-04, 9.99196627e-01],
#        [1.00000000e+00, 1.90201854e-39],
#        [3.15475806e-02, 9.68452419e-01],
#        [1.31125434e-01, 8.68874566e-01],
#        [4.01692986e-06, 9.99995983e-01],
#        [3.84721617e-02, 9.61527838e-01],
#        [5.52875556e-05, 9.99944712e-01],
#        [1.06740760e-04, 9.99893259e-01],
#        [1.21474750e-06, 9.99998785e-01],
#        [1.00000000e+00, 1.08597402e-10],
#        [9.99995428e-01, 4.57192812e-06],
#        [1.05947742e-07, 9.99999894e-01],
#        [6.04129574e-07, 9.99999396e-01],
#        [8.12779080e-07, 9.99999187e-01],
#        [2.33395429e-05, 9.99976660e-01],
#        [7.03456502e-02, 9.29654350e-01],
#        [4.46001456e-01, 5.53998544e-01],
#        [2.89033740e-01, 7.10966260e-01],
#        [1.00000000e+00, 2.96364152e-11],
#        [2.54562999e-04, 9.99745437e-01],
#        [8.08294740e-05, 9.99919171e-01],
#        [3.29160119e-02, 9.67083988e-01],
#        [1.41721231e-04, 9.99858279e-01],
#        [1.00000000e+00, 2.62850405e-18],
#        [7.79103315e-02, 9.22089669e-01],
#        [3.02486835e-07, 9.99999698e-01],
#        [4.20686141e-04, 9.99579314e-01],
#        [1.76783896e-05, 9.99982322e-01],
#        [1.43666340e-02, 9.85633366e-01],
#        [3.96365470e-07, 9.99999604e-01],
#        [1.00000000e+00, 1.76862820e-10],
#        [2.05560805e-03, 9.97944392e-01],
#        [1.96360207e-02, 9.80363979e-01],
#        [1.56530405e-05, 9.99984347e-01],
#        [1.00000000e+00, 1.51354805e-14],
#        [4.62115586e-04, 9.99537884e-01],
#        [1.00000000e+00, 4.14578561e-12],
#        [6.51597937e-07, 9.99999348e-01],
#        [4.23111391e-07, 9.99999577e-01],
#        [1.12596116e-06, 9.99998874e-01],
#        [2.47057214e-08, 9.99999975e-01],
#        [9.99926508e-01, 7.34920096e-05],
#        [4.83454438e-02, 9.51654556e-01],
#        [1.41996966e-02, 9.85800303e-01],
#        [3.45293756e-05, 9.99965471e-01],
#        [2.25276900e-05, 9.99977472e-01],
#        [4.02927523e-05, 9.99959707e-01],
#        [2.99012563e-07, 9.99999701e-01],
#        [1.00000000e+00, 6.29164804e-14],
#        [1.51438674e-04, 9.99848561e-01],
#        [6.63723176e-05, 9.99933628e-01],
#        [2.06761203e-03, 9.97932388e-01],
#        [8.10212160e-04, 9.99189788e-01],
#        [1.00000000e+00, 2.58497186e-32],
#        [1.25683592e-04, 9.99874316e-01],
#        [1.00000000e+00, 8.36342256e-12],
#        [9.44606865e-01, 5.53931351e-02],
#        [9.43349594e-04, 9.99056650e-01],
#        [3.54773511e-03, 9.96452265e-01],
#        [1.00000000e+00, 2.92614280e-24],
#        [1.90953585e-05, 9.99980905e-01],
#        [2.50286729e-04, 9.99749713e-01],
#        [6.00159938e-04, 9.99399840e-01],
#        [4.34207696e-01, 5.65792304e-01],
#        [9.99999263e-01, 7.37464029e-07],
#        [1.00000000e+00, 6.00599875e-13],
#        [1.00000000e+00, 4.13115726e-13],
#        [9.99998787e-01, 1.21324067e-06],
#        [9.99997327e-01, 2.67289627e-06],
#        [2.78006690e-04, 9.99721993e-01],
#        [1.81285733e-05, 9.99981871e-01],
#        [4.65284204e-04, 9.99534716e-01],
#        [2.38640168e-04, 9.99761360e-01],
#        [8.50665632e-06, 9.99991493e-01],
#        [1.00000000e+00, 8.02181146e-24],
#        [1.08970359e-04, 9.99891030e-01],
#        [1.00000000e+00, 6.21709466e-12],
#        [9.99984777e-01, 1.52232445e-05],
#        [1.10191276e-04, 9.99889809e-01],
#        [8.12546724e-07, 9.99999187e-01],
#        [5.14413026e-04, 9.99485587e-01],
#        [1.00000000e+00, 3.58196095e-11],
#        [1.00000000e+00, 1.41507917e-28],
#        [8.56775453e-04, 9.99143225e-01],
#        [9.05265187e-05, 9.99909473e-01],
#        [9.99633672e-01, 3.66328455e-04],
#        [1.19563171e-01, 8.80436829e-01],
#        [9.94179434e-01, 5.82056595e-03],
#        [1.71166721e-04, 9.99828833e-01],
#        [8.08430545e-03, 9.91915695e-01],
#        [9.99528996e-01, 4.71004013e-04],
#        [5.69489975e-05, 9.99943051e-01],
#        [3.33875408e-06, 9.99996661e-01],
#        [1.00000000e+00, 6.91911052e-17],
#        [3.84328223e-06, 9.99996157e-01],
#        [6.44303537e-05, 9.99935570e-01],
#        [9.48371173e-01, 5.16288274e-02],
#        [8.62714992e-01, 1.37285008e-01],
#        [1.00000000e+00, 2.08989250e-47],
#        [2.53272324e-05, 9.99974673e-01],
#        [8.01890310e-08, 9.99999920e-01],
#        [1.00000000e+00, 2.34393888e-25],
#        [1.62965901e-06, 9.99998370e-01],
#        [2.97166190e-04, 9.99702834e-01],
#        [4.92280572e-09, 9.99999995e-01],
#        [2.23425710e-06, 9.99997766e-01]])

# %%
probs = predicoes[:, 1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, tresholds = roc_curve(y_teste, probs)

# %%
print("fpr: ", fpr)
print("tpr: ", tpr)
print("tresholds: ", tresholds)
# Out:
# fpr:  [0.         0.         0.         0.03225806 0.03225806 0.11290323
#  0.11290323 1.        ]
# tpr:  [0.         0.00917431 0.95412844 0.95412844 0.99082569 0.99082569
#  1.         1.        ]
# tresholds:  [2.00000000e+00 9.99999995e-01 8.80436829e-01 8.48441969e-01
#  6.05392216e-01 1.56860266e-01 1.37285008e-01 2.08989250e-47]

# %%
import matplotlib.pyplot as plt

plt.scatter(fpr, tpr)
plt.show()

# %%
print(roc_auc_score(y_teste, probs))
# Out:
# 0.9977804084048535
